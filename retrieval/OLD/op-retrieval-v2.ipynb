# %%
import os
import warnings
from datetime import datetime

import matplotlib
matplotlib.use('agg')

import numpy as np
import pyart
from matplotlib import pyplot as plt
import cftime

import radar_codes
import filtering
import phase
import hydrometeors
import attenuation
import rainrate
import file_util
import gridding

import dask
import dask.bag as db
from dask.diagnostics import ProgressBar

warnings.simplefilter('ignore')
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
#config
vol_root = '/g/data/rq0/level_1/odim_pvol'
cf_root = '/g/data/kl02/jss548/PST/dprain/dprain-retreival/cfradial'
rf_root = '/g/data/kl02/jss548/PST/dprain/dprain-retreival/rfgrid'
img_root = '/g/data/kl02/jss548/PST/dprain/dprain-retreival/img'
VERBOSE = True

rid = 31
date_str = '20210119'

#rid = 71
#date_str = '20200119'
#date_str = '20200911'
# rid = 66
# date_str = '20200309'

NCPU = 10

refl_offset = 0
zdr_offset = 0

if refl_offset != 0 or zdr_offset != 0:
    print('WARNING: IN CALIBRATION TESTING MODE')

# %%
def buffer(vol_ffn):
    try:
        torrentfields(vol_ffn)
    except Exception as e:
        print('failed on', vol_ffn,'with',e)

# %%
def torrentfields(vol_ffn):

    print('processing', vol_ffn)

    #read radar volume
    radar = pyart.aux_io.read_odim_h5(vol_ffn, file_field_names=True)
    #get time
    valid_time = cftime.num2pydate(radar.time['data'][0], radar.time['units'])

    #get radar band
    wavelength = radar_codes.get_wavelength(vol_ffn)
    if wavelength<8:
        band = 'C'
    else:
        band = 'S'
    if VERBOSE:
        print('band', band)
        
    ##################################################################################################
    #
    # Preprocessing
    #
    ##################################################################################################

    #offset refl if required for testing
    refl = radar.fields['DBZH']['data'] + refl_offset
    radar.add_field_like('DBZH', 'DBZH', refl, replace_existing=True)
    zdr = radar.fields['ZDR']['data'] + zdr_offset
    radar.add_field_like('ZDR', 'ZDR', zdr, replace_existing=True)
    
    # Correct RHOHV
    rho_corr = radar_codes.correct_rhohv(radar, snr_name='SNRH')
    radar.add_field_like('RHOHV', 'RHOHV_CORR', rho_corr, replace_existing=True)

    # Correct ZDR
    corr_zdr = radar_codes.correct_zdr(radar, snr_name='SNRH')
    radar.add_field_like('ZDR', 'ZDR_CORR', corr_zdr, replace_existing=True)

#     from importlib import reload
#     reload(radar_codes)
    
    # Temperature    
    height, temperature, isom = radar_codes.temperature_profile_access(radar, source='access')
    radar.add_field('temperature', temperature, replace_existing=True)
    radar.add_field('height', height, replace_existing=True)
    radar.add_field('height_over_isom', isom, replace_existing=True)

    # GateFilter
    gatefilter = filtering.do_gatefilter(radar,
                                         refl_name='DBZH',
                                         phidp_name="PHIDP",
                                         rhohv_name='RHOHV_CORR',
                                         zdr_name="ZDR_CORR",
                                         snr_name='SNRH')
    #create fake NCP
    ncp = pyart.config.get_metadata('normalized_coherent_power')
    ncp['data'] = np.zeros_like(radar.fields['RHOHV']['data'])
    ncp['data'][gatefilter.gate_included] = 1
    radar.add_field('NCP', ncp, replace_existing=True)

    # phidp filtering
    phidp, kdp = phase.phidp_giangrande(radar, gatefilter, rhv_field='RHOHV_CORR', refl_field='DBZH')
    radar.add_field('PHIDP_VAL', phidp, replace_existing=True)
    radar.add_field('KDP_VAL', kdp, replace_existing=True)
    kdp_field_name = 'KDP_VAL'
    phidp_field_name = 'PHIDP_VAL'

    #first try to use exisiting NCAR HCA into a field. Sometimes it is missing due a missing DP fields.
    try:
        hca_field = hydrometeors.extract_ncar_pid(radar, vol_ffn)
    except:
        #insert CSU HCA if NCAR PID is not in the file
        hca_field = hydrometeors.csu_hca(radar,
                                          gatefilter,
                                          kdp_name=kdp_field_name,
                                          zdr_name='ZDR_CORR',
                                          rhohv_name='RHOHV_CORR',
                                          refl_name='DBZH',
                                          band=band)
    radar.add_field('radar_echo_classification', hca_field, replace_existing=True)
    
    ##################################################################################################
    #
    # Retrievals
    #
    ##################################################################################################
#     from importlib import reload
#     reload(rainrate)
#     reload(attenuation)

    #index index of lowest sweep
    first_sweep_idx = np.argmin(radar.fixed_angle['data'])
    #estimate alpha
    alpha, alpha_method = attenuation.estimate_alpha_zhang2020(radar, band, first_sweep_idx,
                                           refl_field='DBZH', zdr_field='ZDR_CORR', rhohv_field='RHOHV_CORR',
                                           verbose=VERBOSE)

    #estimate specific attenuation
    radar = attenuation.retrieve_zphi(radar, band, alpha=alpha, alpha_method=alpha_method,
                                     refl_field='DBZH', phidp_field=phidp_field_name, rhohv_field='RHOHV_CORR')

    #estimate rainfall
    radar = rainrate.conventional(radar, alpha=92, beta=1.7, refl_field='corrected_reflectivity')
    radar = rainrate.polarimetric(radar, band, refl_field='corrected_reflectivity',
                                  kdp_field=kdp_field_name, phidp_field=phidp_field_name, rhohv_field='RHOHV_CORR', min_delta_phidp=1.)
    
    ##################################################################################################
    #
    # Write outputs CF Radial
    #
    ##################################################################################################
    
    #create paths
    cf_path = f'{cf_root}/{rid:02}/{date_str}'
    if not os.path.exists(cf_path):
        os.makedirs(cf_path)
    cf_fn = f'{rid:02}_{valid_time.strftime("%Y%m%d_%H%M%S")}.vol.nc' #this filename should match
    cf_ffn = f'{cf_path}/{cf_fn}'
    #write to cf
    pyart.io.write_cfradial(cf_ffn, radar)
    
    ##################################################################################################
    #
    # Create and write grid
    #
    ##################################################################################################
        
    # grid first two sweeps (second sweep used as a fallback where the lower grid has no data)
    sort_idx = np.argsort(radar.fixed_angle['data'])
    data_sweep1 = radar.get_field(sort_idx[0], 'hybrid_rainrate', copy=True).filled(np.nan)
    data_sweep2 = radar.get_field(sort_idx[1], 'hybrid_rainrate', copy=True).filled(np.nan)
    data_combined = np.nanmax(np.stack((data_sweep1, data_sweep2), axis=2), axis=2)
    #build metadata and grid
    r = radar.range['data']
    th = 450 - radar.get_azimuth(sort_idx[0], copy=False)
    th[th < 0] += 360
    R, A = np.meshgrid(r, th)
    x = R * np.cos(np.pi * A / 180)
    y = R * np.sin(np.pi * A / 180)
    xgrid = np.linspace(-127750,127750,512)
    xgrid, ygrid = np.meshgrid(xgrid, xgrid)
    gatespacing = r[1]-r[0]
    rain_grid_2d = gridding.KDtree_nn_interp(data_combined, x, y, xgrid, ygrid, nnearest = 16, maxdist = 2500)
    
    #extract metadata for RF3 grids
    standard_lat_1, standard_lat_2 = file_util.rf_standard_parallel_lookup(rid)
    if standard_lat_1 is None:
        print('failed to lookup standard parallels')
    rf_lon0, rf_lat0 = file_util.rf_grid_centre_lookup(rid)
    if rf_lon0 is None:
        print('failed to lookup rf grid centre coordinates')
    
    #create paths
    rf_path = f'{rf_root}/{rid:02}/{date_str}'
    if not os.path.exists(rf_path):
        os.makedirs(rf_path)
    rf_fn = f'{rid}_{valid_time.strftime("%Y%m%d_%H%M%S")}.prcp-rrate.nc' #this filename should match
    rf_ffn = f'{rf_path}/{rf_fn}'
    
    #write to nc
    file_util.write_rf_nc(rf_ffn, rid, valid_time.timestamp(), rain_grid_2d, rf_lon0, rf_lat0, (standard_lat_1, standard_lat_2))
    
    #create image and save to file
    ###################################################################################################################
    tilt = sort_idx[0] #first tilt
    ylim = [-128, 128]
    xlim = [-128, 128]

    fig = plt.figure(figsize=[16,8])
    display = pyart.graph.RadarDisplay(radar)

    ax = plt.subplot(231)
    display.plot_ppi('DBZH', tilt, vmin=0, vmax=60, cmap='pyart_HomeyerRainbow')
    ax.set_xlabel('')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    ax = plt.subplot(232)
    display.plot_ppi('KDP_VAL', tilt, vmin=0, vmax=4, cmap='pyart_HomeyerRainbow')
    ax.set_xlabel('')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    ax = plt.subplot(233)
    display.plot_ppi('PHIDP_VAL', tilt, vmin=0, vmax=25, cmap='pyart_HomeyerRainbow')
    ax.set_xlabel('')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    ax = plt.subplot(234)
    display.plot_ppi('zr_rainrate', tilt, vmin=0.2, vmax=75, cmap='pyart_RRate11', title='SP retrieval')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    ax = plt.subplot(235)
    display.plot_ppi('hybrid_rainrate', tilt, vmin=0.2, vmax=75, cmap='pyart_RRate11', title='DP retrieval')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    ax = plt.subplot(236)
    ax.set_title('DP gridded data')
    img = plt.imshow(np.flipud(rain_grid_2d), vmin=0, vmax=75, cmap=pyart.graph.cm._generate_cmap('RRate11',100))
    cbar = fig.colorbar(img, ax=ax)
    cbar.set_label('DP rain rate (mm/hr)')
    
    img_path = f'{img_root}/{rid:02}/{date_str}'
    if not os.path.exists(img_path):
        os.makedirs(img_path)
    img_fn = f'{rid:02}_{valid_time.strftime("%Y%m%d_%H%M%S")}.jpg' #this filename should match
    img_ffn = f'{img_path}/{img_fn}'
    plt.savefig(img_ffn, dpi=100)
    fig.clf()
    plt.close()
    ###################################################################################################################

# %%
def manager(date_str, rid):

    #unpack and list daily zip
    vol_zip = f'{vol_root}/{rid:02}/{date_str[0:4]}/vol/{rid:02}_{date_str}.pvol.zip'
    temp_dir = True
    vol_ffn_list = file_util.unpack_zip(vol_zip)

    
#     for vol_ffn in vol_ffn_list[60:]:
#         torrentfields(vol_ffn)
    #run retrieval
    i            = 0
    n_files      = len(vol_ffn_list)   
    for flist_chunk in file_util.chunks(vol_ffn_list, NCPU): #CUSTOM RANGE USED
        bag = db.from_sequence(flist_chunk).map(buffer)
        _ = bag.compute()
        i += NCPU
        del bag
        print('processed: ' + str(round(i/n_files*100,2)))
        
    #clean up
    temp_vol_dir = os.path.dirname(vol_ffn_list[0])
    if '/tmp' in temp_vol_dir:
        os.system('rm -rf '+ temp_vol_dir)

# %%
manager(date_str, rid)

# %%
#unpack and list daily zip
vol_zip = f'{vol_root}/{rid:02}/{date_str[0:4]}/vol/{rid:02}_{date_str}.pvol.zip'
temp_dir = True
vol_ffn_list = file_util.unpack_zip(vol_zip)

# %%
for vol_ffn in vol_ffn_list:
    torrentfields(vol_ffn)
# Out:
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_000029.pvol.h5
# band C
# defaults 0.07851402206955327 0.09803630895779822
# temp: 17.92802456408414 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09803630895779822
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_000529.pvol.h5
# band C
# defaults 0.07510024044738413 0.09427681712173652
# temp: 19.48292395928757 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09427681712173652
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_001029.pvol.h5
# band C
# defaults 0.0742361680572847 0.09332524099418063
# temp: 19.87648915632671 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09332524099418063
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_001529.pvol.h5
# band C
# defaults 0.0735724902282947 0.09259435318235931
# temp: 20.178779217356087 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09259435318235931
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_002029.pvol.h5
# band C
# defaults 0.07338396415894725 0.09238673526854965
# temp: 20.26464852701104 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 3.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09238673526854965
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_002529.pvol.h5
# band C
# defaults 0.07276017563724156 0.0916997763138373
# temp: 20.548769921547912 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0916997763138373
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_003029.pvol.h5
# band C
# defaults 0.07235792821573325 0.09125679370258388
# temp: 20.731984415516624 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09125679370258388
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_003529.pvol.h5
# band C
# defaults 0.07077294629869588 0.08951130226906295
# temp: 21.453907402097066 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08951130226906295
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_004029.pvol.h5
# band C
# defaults 0.06900551084118449 0.08756488040946608
# temp: 22.258933800416994 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08756488040946608
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_004529.pvol.h5
# band C
# defaults 0.06861168901998371 0.08713117665054596
# temp: 22.438310626288445 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08713117665054596
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_005029.pvol.h5
# band C
# defaults 0.06846889072168047 0.08697391731292803
# temp: 22.5033519828374 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08697391731292803
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_005529.pvol.h5
# band C
# defaults 0.06810185144923614 0.08656970834440247
# temp: 22.670529970741907 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08656970834440247
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_010029.pvol.h5
# band C
# defaults 0.06774171409556554 0.08617310024498773
# temp: 22.83456429261419 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08617310024498773
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_010529.pvol.h5
# band C
# defaults 0.06787758222556849 0.08632272760316727
# temp: 22.772679469110226 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08632272760316727
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_011029.pvol.h5
# band C
# defaults 0.06811693815952746 0.08658632287059387
# temp: 22.66365831950468 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08658632287059387
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_011529.pvol.h5
# band C
# defaults 0.06643832919692767 0.08473772287525379
# temp: 23.428226282428753 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08473772287525379
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_012029.pvol.h5
# band C
# defaults 0.0664654837944648 0.08476762739143298
# temp: 23.415857984757544 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08476762739143298
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_012529.pvol.h5
# band C
# defaults 0.06719460968336989 0.0855705911220357
# temp: 23.08375783039403 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0855705911220357
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_013029.pvol.h5
# band C
# defaults 0.0671634469641266 0.08553627258571697
# temp: 23.097951735765605 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08553627258571697
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_013529.pvol.h5
# band C
# defaults 0.06641762659455287 0.08471492374126471
# temp: 23.437655843975 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08471492374126471
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_014029.pvol.h5
# band C
# defaults 0.06629271535276922 0.08457736286429814
# temp: 23.494550055673322 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_061029.pvol.h5
# band C
# defaults 0.07136171973587346 0.0901597001970337
# temp: 21.185734577147134 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0901597001970337
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_061529.pvol.h5
# band C
# defaults 0.0750536369770453 0.09422549416506783
# temp: 19.5041507733795 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09422549416506783
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_062029.pvol.h5
# band C
# defaults 0.07260417492856212 0.09152797757109067
# temp: 20.61982467385009 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09152797757109067
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_062529.pvol.h5
# band C
# defaults 0.07212552684834958 0.09100085728365931
# temp: 20.837837919221325 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09100085728365931
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_063029.pvol.h5
# band C
# defaults 0.07029752065953507 0.08898773075603109
# temp: 21.670452899323585 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08898773075603109
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_063529.pvol.h5
# band C
# defaults 0.06937083031748158 0.08796719541982712
# temp: 22.092539140295337 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08796719541982712
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_064029.pvol.h5
# band C
# defaults 0.07086876507622662 0.08961682451733124
# temp: 21.410264142005634 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08961682451733124
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_064529.pvol.h5
# band C
# defaults 0.07115478355351229 0.08993180779667617
# temp: 21.279989271914232 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08993180779667617
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_065029.pvol.h5
# band C
# defaults 0.07174495683430065 0.09058174732900506
# temp: 21.011178850238828 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09058174732900506
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_065529.pvol.h5
# band C
# defaults 0.07188247462866178 0.0907331914113847
# temp: 20.94854264237678 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0907331914113847
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_070029.pvol.h5
# band C
# defaults 0.07223605708833171 0.09112258080930966
# temp: 20.787493924695188 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09112258080930966
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_070529.pvol.h5
# band C
# defaults 0.07164990307239757 0.0904770675687237
# temp: 21.054473663221327 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0904770675687237
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_071029.pvol.h5
# band C
# defaults 0.07069240503923586 0.0894226046776764
# temp: 21.49059210237492 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0894226046776764
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_071529.pvol.h5
# band C
# defaults 0.06950260645958439 0.08811231639862846
# temp: 22.032518123623596 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08811231639862846
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_072029.pvol.h5
# band C
# defaults 0.06839564713991109 0.08689325642767465
# temp: 22.536712757954408 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08689325642767465
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_072529.pvol.h5
# band C
# defaults 0.06717388816529031 0.08554777115676754
# temp: 23.093196007610878 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08554777115676754
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_073029.pvol.h5
# band C
# defaults 0.06698999927625827 0.08534526002583612
# temp: 23.176953187766667 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08534526002583612
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_073529.pvol.h5
# band C
# defaults 0.06679299828076751 0.0851283089386799
# temp: 23.266682632308118 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0851283089386799
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_074029.pvol.h5
# band C
# defaults 0.06656466126150938 0.08487684846030688
# temp: 23.370684918465322 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 2.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08487684846030688
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_074529.pvol.h5
# band C
# defaults 0.06712018451656712 0.08548862899382705
# temp: 23.117656790449956 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08548862899382705
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_075029.pvol.h5
# band C
# defaults 0.06828935163326251 0.08677619648252166
# temp: 22.58512792837052 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.08677619648252166
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_075529.pvol.h5
# band C
# defaults 0.06924890266696235 0.0878329202793962
# temp: 22.148074394460327 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0878329202793962
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_080029.pvol.h5
# band C
# defaults 0.07299820780084494 0.0919619137540226
# temp: 20.440351719041242 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0919619137540226
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_080529.pvol.h5
# band C
# defaults 0.07517276570847442 0.0943566869427018
# temp: 19.449890362799167 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0943566869427018
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_081029.pvol.h5
# band C
# defaults 0.07441148364040788 0.09351831060918056
# temp: 19.796636920788938 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09351831060918056
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_081529.pvol.h5
# band C
# defaults 0.07342214966403526 0.09242878778113628
# temp: 20.247255903422783 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09242878778113628
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_082029.pvol.h5
# band C
# defaults 0.07277663814803922 0.09171790596646152
# temp: 20.54127162466899 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09171790596646152
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_082529.pvol.h5
# band C
# defaults 0.07336139374344017 0.09236187916988053
# temp: 20.27492883468906 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09236187916988053
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_083029.pvol.h5
# band C
# defaults 0.07603178770413749 0.09530270122748218
# temp: 19.05862550483375 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09530270122748218
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_083529.pvol.h5
# band C
# defaults 0.07727413022569071 0.09667085452031171
# temp: 18.492766920660113 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 5.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09667085452031171
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_084029.pvol.h5
# band C
# defaults 0.07845228247073732 0.09796831705222261
# temp: 17.956145538265847 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09796831705222261
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_084529.pvol.h5
# band C
# defaults 0.07905797699633285 0.0986353496501299
# temp: 17.68026554482676 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0986353496501299
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_085029.pvol.h5
# band C
# defaults 0.0791249042345811 0.09870905454213895
# temp: 17.649781719616897 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 3.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09870905454213895
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_085529.pvol.h5
# band C
# defaults 0.07891907053100851 0.09848237626748241
# temp: 17.74353426052903 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 0.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09848237626748241
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_090029.pvol.h5
# band C
# defaults 0.07512178934595927 0.09430054825548663
# temp: 19.473108929191856 C
#
#
# case 1 valid bins 2
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 2
# case 2 thresholds 11
# case 3 valid bins 2
# case 3 thresholds 9
# case 4 False
# case 4 total count 6.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09430054825548663
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_090529.pvol.h5
# band C
# defaults 0.07484112473281943 0.09399146102069736
# temp: 19.600945236702607 C
#
#
# case 1 valid bins 2
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 2
# case 2 thresholds 11
# case 3 valid bins 2
# case 3 thresholds 9
# case 4 False
# case 4 total count 2.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09399146102069736
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_091029.pvol.h5
# band C
# defaults 0.07448696283445685 0.09360143350490913
# temp: 19.762257875446657 C
#
#
# case 1 valid bins 4
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 6
# case 2 thresholds 11
# case 3 valid bins 6
# case 3 thresholds 9
# case 4 False
# case 4 total count 2.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09360143350490913
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_091529.pvol.h5
# band C
# defaults 0.07404296100787605 0.09311246806219098
# temp: 19.964490545262557 C
#
#
# case 1 valid bins 3
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 7
# case 2 thresholds 11
# case 3 valid bins 7
# case 3 thresholds 9
# case 4 False
# case 4 total count 2.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09311246806219098
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_092029.pvol.h5
# band C
# defaults 0.07334221665268964 0.09234076003453578
# temp: 20.283663560605945 C
#
#
# case 1 valid bins 3
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 7
# case 2 thresholds 11
# case 3 valid bins 7
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09234076003453578
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_092529.pvol.h5
# band C
# defaults 0.07274169367662392 0.09167942270375126
# temp: 20.557188031599217 C
#
#
# case 1 valid bins 4
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 8
# case 2 thresholds 11
# case 3 valid bins 8
# case 3 thresholds 9
# case 4 False
# case 4 total count 5.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09167942270375126
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_093029.pvol.h5
# band C
# defaults 0.07244389863781807 0.09135147026240592
# temp: 20.692826855924356 C
#
#
# case 1 valid bins 4
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 8
# case 2 thresholds 11
# case 3 valid bins 8
# case 3 thresholds 9
# case 4 False
# case 4 total count 4.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09135147026240592
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_093529.pvol.h5
# band C
# defaults 0.07249817002915253 0.091411237662678
# temp: 20.668107479320184 C
#
#
# case 1 valid bins 5
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 9
# case 2 thresholds 11
# case 3 valid bins 9
# case 3 thresholds 9
# case 4 False
# case 4 total count 10.0
# case 4 min 50
#
# 3: fitted 10-40dbz
# alpha value 0.07785598730586653
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_094029.pvol.h5
# band C
# defaults 0.07232798316478925 0.09122381614660219
# temp: 20.745623700847528 C
#
#
# case 1 valid bins 5
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 9
# case 2 thresholds 11
# case 3 valid bins 9
# case 3 thresholds 9
# case 4 False
# case 4 total count 9.0
# case 4 min 50
#
# 3: fitted 10-40dbz
# alpha value 0.08000082477136734
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_094529.pvol.h5
# band C
# defaults 0.07245920099656819 0.09136832227555755
# temp: 20.68585698174985 C
#
#
# case 1 valid bins 4
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 8
# case 2 thresholds 11
# case 3 valid bins 8
# case 3 thresholds 9
# case 4 False
# case 4 total count 8.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09136832227555755
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_095029.pvol.h5
# band C
# defaults 0.07244749713572701 0.09135543317656039
# temp: 20.691187822488263 C
#
#
# case 1 valid bins 4
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 6
# case 2 thresholds 11
# case 3 valid bins 6
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09135543317656039
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_095529.pvol.h5
# band C
# defaults 0.07257751877030699 0.09149862197063571
# temp: 20.63196594383648 C
#
#
# case 1 valid bins 1
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 1
# case 2 thresholds 11
# case 3 valid bins 1
# case 3 thresholds 9
# case 4 False
# case 4 total count 12.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09149862197063571
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_100029.pvol.h5
# band C
# defaults 0.07282625430773906 0.0917725467044973
# temp: 20.518672599526724 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 18.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0917725467044973
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_100529.pvol.h5
# band C
# defaults 0.07291059677755717 0.09186543045097226
# temp: 20.48025653493183 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 18.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09186543045097226
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_101029.pvol.h5
# band C
# defaults 0.07319987993247427 0.0921840090185521
# temp: 20.34849467890035 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 14.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.0921840090185521
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_101529.pvol.h5
# band C
# defaults 0.07374127209033132 0.09278022741294314
# temp: 20.101902942231238 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 7.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09278022741294314
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_102029.pvol.h5
# band C
# defaults 0.07458905174188346 0.09371386085278935
# temp: 19.71575871469667 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 2.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09371386085278935
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_102529.pvol.h5
# band C
# defaults 0.07538250753305942 0.09458766910983496
# temp: 19.35435776221388 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 3.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09458766910983496
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_103529.pvol.h5
# band C
# defaults 0.0758414763590671 0.09509311724488184
# temp: 19.145307966719606 C
#
#
# case 1 valid bins 0
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 0
# case 2 thresholds 11
# case 3 valid bins 0
# case 3 thresholds 9
# case 4 False
# case 4 total count 3.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09509311724488184
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_104029.pvol.h5
# band C
# defaults 0.07565338994554921 0.09488598351040314
# temp: 19.230977023206915 C
#
#
# case 1 valid bins 2
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 2
# case 2 thresholds 11
# case 3 valid bins 2
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09488598351040314
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_104529.pvol.h5
# band C
# defaults 0.07532081186571554 0.09451972558462718
# temp: 19.382458726615553 C
#
#
# case 1 valid bins 2
# case 1 thresholds 8
# case 1a valid bins 0
# case 1a thresholds 3
# case 2 valid bins 2
# case 2 thresholds 11
# case 3 valid bins 2
# case 3 thresholds 9
# case 4 False
# case 4 total count 1.0
# case 4 min 50
#
# 5: default stratiform
# alpha value 0.09451972558462718
# processing /jobfs/22921372.gadi-pbs/tmps061eyq6/31_20210119_105029.pvol.h5
# band C
