# %%
import os
import warnings
from datetime import datetime

import numpy as np
import pyart
from matplotlib import pyplot as plt
import cftime

import radar_codes
import filtering
import phase
import hydrometeors
import attenuation
import rainrate
import file_util

warnings.simplefilter('ignore')
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
#config
vol_root = '/g/data/rq0/level_1/odim_pvol'
rid = 2
date_str = '20200119'
cf_root = '/g/data/kl02/jss548/PST/polarimetric_rain/cfradial'
rf_root = '/g/data/kl02/jss548/PST/polarimetric_rain/rf3_instant_rainrate'
VERBOSE = False

# %%
#unpack and list daily zip
vol_zip = f'{vol_root}/{rid:02}/{date_str[0:4]}/vol/{rid:02}_{date_str}.pvol.zip'
temp_dir = True
vol_ffn_list = file_util.unpack_zip(vol_zip)

# %%
#init alpha dictcontinous
alpha_dict = {'z_pairs':[], 'zdr_pairs':[], 'alpha_ts':[], 'dt_ts':[]}

for vol_ffn in vol_ffn_list:
    print('processing', vol_ffn)
    
    #read radar volume
    radar = pyart.aux_io.read_odim_h5(vol_ffn, file_field_names=True)
    #get time
    valid_time = cftime.num2pydate(radar.time['data'][0], radar.time['units'])
    
    #get radar band
    wavelength = radar_codes.get_wavelength(vol_ffn)
    if wavelength<8:
        band = 'C'
    else:
        band = 'S'
    if VERBOSE:
        print('band', band)
    
    ##################################################################################################
    #
    # Preprocessing
    #
    ##################################################################################################
    
    # Correct RHOHV
    rho_corr = radar_codes.correct_rhohv(radar, snr_name='SNRH')
    radar.add_field_like('RHOHV', 'RHOHV_CORR', rho_corr, replace_existing=True)

    # Correct ZDR
    corr_zdr = radar_codes.correct_zdr(radar, snr_name='SNRH')
    radar.add_field_like('ZDR', 'ZDR_CORR', corr_zdr, replace_existing=True)

    # Temperature    
    height, temperature, isom = radar_codes.temperature_profile_access(radar)
    radar.add_field('temperature', temperature, replace_existing=True)
    radar.add_field('height', height, replace_existing=True)
    radar.add_field('height_over_isom', isom, replace_existing=True)

    # GateFilter
    gatefilter = filtering.do_gatefilter(radar,
                                         refl_name='DBZH',
                                         phidp_name="PHIDP",
                                         rhohv_name='RHOHV_CORR',
                                         zdr_name="ZDR_CORR",
                                         snr_name='SNRH')
    #create fake NCP
    ncp = pyart.config.get_metadata('normalized_coherent_power')
    ncp['data'] = np.zeros_like(radar.fields['RHOHV']['data'])
    ncp['data'][gatefilter.gate_included] = 1
    radar.add_field('NCP', ncp, replace_existing=True)

    # phidp filtering
    phidp, kdp = phase.phidp_giangrande(radar, gatefilter, rhv_field='RHOHV_CORR', refl_field='DBZH')
    radar.add_field('PHIDP_VAL', phidp, replace_existing=True)
    radar.add_field('KDP_VAL', kdp, replace_existing=True)
    kdp_field_name = 'KDP_VAL'
    phidp_field_name = 'PHIDP_VAL'

    # Hydrometeors classification
    hydro_class = hydrometeors.hydrometeor_classification(radar,
                                                          gatefilter,
                                                          kdp_name=kdp_field_name,
                                                          zdr_name='ZDR_CORR',
                                                          rhohv_name='RHOHV_CORR',
                                                          refl_name='DBZH',
                                                          band=band)

    radar.add_field('radar_echo_classification', hydro_class, replace_existing=True)
    
    ##################################################################################################
    #
    # Retrievals
    #
    ##################################################################################################

    #estimate alpha
    alpha_dict = attenuation.estimate_alpha_wang2019(radar, alpha_dict, band,
                                           refl_field='DBZH', zdr_field='ZDR_CORR', rhohv_field='RHOHV_CORR',
                                           verbose=True)

    #estimate specific attenuation
    alpha = alpha_dict['alpha_ts'][-1]
    if VERBOSE:
        print('alpha', alpha)
    radar = attenuation.retrieve_zphi(radar, band, alpha=alpha,
                                     refl_field='DBZH', phidp_field=phidp_field_name, rhohv_field='RHOHV_CORR')

    #estimate rainfall
    radar = rainrate.conventional(radar, alpha=92, beta=1.7, refl_field='corrected_reflectivity')
    radar = rainrate.polarimetric(radar, band, refl_field='corrected_reflectivity', kdp_field=kdp_field_name, rhohv_field='RHOHV_CORR')
    
    
    ##################################################################################################
    #
    # Write outputs CF Radial
    #
    ##################################################################################################
    
    #write to cf output
    
    #create paths
    cf_path = f'{cf_root}/{rid:02}/{date_str}'
    if not os.path.exists(cf_path):
        os.makedirs(cf_path)
    cf_fn = f'{rid:02}_{valid_time.strftime("%Y%m%d_%H%M%S")}.vol.nc' #this filename should match
    cf_ffn = f'{cf_path}/{cf_fn}'
    #write to cf
    pyart.io.write_cfradial(cf_ffn, radar)
    
    ##################################################################################################
    #
    # Create and write grid
    #
    ##################################################################################################
        
    # grid RF
    GRID_SHAPE = (6, 512, 512)
    GRID_LIMITS = ((0, 2500), (-128000.0, 128000.0), (-128000.0, 128000.0))
    GRID_ROI = 2500
    hydrid_gatefilter = pyart.correct.GateFilter(radar)
    hydrid_gatefilter.exclude_masked('hybrid_rainrate')
    radar_lat = radar.latitude['data'][0]
    radar_lon = radar.longitude['data'][0]
    standard_lat_1 = radar_lat+1.0
    standard_lat_2 = radar_lat-1.0
    grid_proj ={'proj':'aea', 'lat_1':standard_lat_1, 'lat_2':standard_lat_2,
               'lon_0':radar_lon, 'lat_0':radar_lat}
    rf_grid = pyart.map.grid_from_radars(
                    radar,
                    grid_shape = (6, 512, 512),
                    grid_limits = ((0, 2500), (-128000.0, 128000.0), (-128000.0, 128000.0)),
                    roi_func = 'constant',
                    grid_projection = grid_proj,
                    gatefilter = hydrid_gatefilter,
                    constant_roi = 2500,
                    weighting_function = 'Barnes2',
                    fields = ['hybrid_rainrate'])
    
    #extract lowest valid values
    rain_grid = rf_grid.fields['hybrid_rainrate']['data']
    rain_grid_mask = np.ma.getmaskarray(rain_grid)
    rain_grid_2d = np.zeros((GRID_SHAPE[1],GRID_SHAPE[2]))
    for i in range(GRID_SHAPE[1]):
        for j in range(GRID_SHAPE[2]):
            col_rain = rain_grid[:,i,j]
            mask = ~np.ma.getmaskarray(col_rain)
            if np.any(mask):
                rain_grid_2d[i,j] = col_rain[np.where(mask)[0][0]]
                
    #create paths
    rf_path = f'{rf_root}/{rid:02}/{date_str}'
    if not os.path.exists(rf_path):
        os.makedirs(rf_path)
    rf_fn = f'{rid}_{valid_time.strftime("%Y%m%d_%H%M%S")}.prcp-rrate.nc' #this filename should match
    rf_ffn = f'{rf_path}/{rf_fn}'
    
    #write to nc
    file_util.write_rf_nc(rf_ffn, rid, valid_time.timestamp(), rain_grid_2d, radar_lon, radar_lat, (standard_lat_1, standard_lat_2))
    
#clean up

temp_vol_dir = os.path.dirname(vol_ffn_list[0])
if '/tmp' in temp_vol_dir:
    os.system('rm -rf '+ temp_vol_dir)
# Out:
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_000028.pvol.h5
# 18.715792456206017
# 0.000467437856560563 0.005676047893742775 0.01736199430775685 0.05 18.715792456206017
# insufficent pairs 0 - Using default alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_000628.pvol.h5
# 18.52768446066947
# 0.0004698456389034308 0.005709305387353637 0.017455446359939404 0.05 18.52768446066947
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_001228.pvol.h5
# 18.78496326676427
# 0.00046655247018541736 0.0056638184944360764 0.01732763024907151 0.05 18.78496326676427
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_001828.pvol.h5
# 18.61631820224834
# 0.0004687111270112213 0.005693634941842492 0.017411413117123024 0.05 18.61631820224834
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_002428.pvol.h5
# 18.809172780394654
# 0.00046624258841094845 0.0056595382524262244 0.017315602962699933 0.05 18.809172780394654
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_003031.pvol.h5
# 18.724534601947454
# 0.0004673259570950726 0.005674502282375689 0.017357651209752505 0.05 18.724534601947454
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_003628.pvol.h5
# 18.341365948811646
# 0.00047223051585521095 0.0057422465002501 0.017548009396630374 0.05 18.341365948811646
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_004231.pvol.h5
# 18.254198734733126
# 0.000473346256195416 0.005757657663699182 0.01759131406858458 0.05 18.254198734733126
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_004828.pvol.h5
# 18.690409142311093
# 0.000467762762978418 0.005680535663639397 0.017374604738099847 0.05 18.690409142311093
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_005428.pvol.h5
# 18.709625773381422
# 0.00046751679010071783 0.005677138163266164 0.017365057915784108 0.05 18.709625773381422
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_010031.pvol.h5
# 18.582042089183958
# 0.0004691498612584454 0.005699694958632276 0.017428441490093413 0.05 18.582042089183958
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_010630.pvol.h5
# 18.43962241604732
# 0.0004709728330745943 0.005724874756842833 0.01749919558370769 0.05 18.43962241604732
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_011228.pvol.h5
# 18.629440257735304
# 0.0004685431647009881 0.005691314962432397 0.0174048940799571 0.05 18.629440257735304
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_011828.pvol.h5
# 17.760224419248445
# 0.0004796691274336199 0.005844992322676874 0.01783672050851737 0.05 17.760224419248445
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_012428.pvol.h5
# 16.06574715572061
# 0.0005013584364067762 0.006144575902868595 0.018678536813038 0.05 16.06574715572061
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_013028.pvol.h5
# 14.442014307803998
# 0.0005221422168601088 0.006431651870380252 0.019485207291882974 0.05 14.442014307803998
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_013628.pvol.h5
# 13.00984513282508
# 0.000540473982299839 0.006684859380516526 0.0201967089380125 0.05 13.00984513282508
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_014228.pvol.h5
# 12.615576382576378
# 0.0005455206223030223 0.006754566095560495 0.020392581653136052 0.05 12.615576382576378
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_014828.pvol.h5
# 11.36262248816881
# 0.0005615584321514392 0.0069760883440917534 0.021015049147877732 0.05 11.36262248816881
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_015428.pvol.h5
# 10.231843096344424
# 0.0005760324083667913 0.007176010140566305 0.021576820349736087 0.05 10.231843096344424
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_020028.pvol.h5
# 10.436461419806164
# 0.0005734132938264811 0.00713983362097827 0.021475165966640297 0.05 10.436461419806164
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_020628.pvol.h5
# 10.288181803735007
# 0.0005753112729121919 0.0071660494570996505 0.021548831279904448 0.05 10.288181803735007
# insufficent pairs 0 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_021231.pvol.h5
# 10.047245126615852
# 0.000578395262379317 0.007208647061614316 0.021668528621097242 0.05 10.047245126615852
# insufficent pairs 616 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_021828.pvol.h5
# 10.408525557129728
# 0.0005737708728687394 0.007144772681499463 0.02148904450321795 0.05 10.408525557129728
# insufficent pairs 1496 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_022428.pvol.h5
# 10.803048823359356
# 0.0005687209750610002 0.007075020968030065 0.021293045344555072 0.05 10.803048823359356
# insufficent pairs 2741 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_023031.pvol.h5
# 10.972490652510592
# 0.0005665521196478644 0.007045063652636126 0.021208866643832737 0.05 10.972490652510592
# insufficent pairs 4233 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_023628.pvol.h5
# 11.305739975559835
# 0.0005622865283128341 0.006986145172321021 0.021043308380141873 0.05 11.305739975559835
# insufficent pairs 5910 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_024228.pvol.h5
# 12.130325137596996
# 0.0005517318382387584 0.006840358515672851 0.02063365447164181 0.05 12.130325137596996
# insufficent pairs 7969 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_024828.pvol.h5
# 12.363489109148345
# 0.0005487473394029012 0.006799135125502571 0.0205178186105751 0.05 12.363489109148345
# insufficent pairs 10275 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_025428.pvol.h5
# 12.633742950273524
# 0.0005452880902364989 0.006751354246391641 0.020383556502304112 0.05 12.633742950273524
# insufficent pairs 12668 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_030028.pvol.h5
# 12.84301982954194
# 0.0005426093461818631 0.006714354094136984 0.02027958774868356 0.05 12.84301982954194
# insufficent pairs 15152 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_030630.pvol.h5
# 13.033001764357673
# 0.0005401775774162218 0.006680765288061562 0.020185204723467107 0.05 13.033001764357673
# insufficent pairs 17549 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_031228.pvol.h5
# 13.080235359098278
# 0.0005395729874035421 0.006672414388511424 0.020161739073599975 0.05 13.080235359098278
# insufficent pairs 19973 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_031828.pvol.h5
# 13.235579347516117
# 0.0005375845843517938 0.00664494957135915 0.020084564180153995 0.05 13.235579347516117
# insufficent pairs 22734 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_032431.pvol.h5
# 13.433116018130548
# 0.000535056114967929 0.006610025087994518 0.019986427962192743 0.05 13.433116018130548
# insufficent pairs 25984 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_033028.pvol.h5
# 13.439364099841395
# 0.0005349761395220302 0.006608920427148041 0.019983323915198796 0.05 13.439364099841395
# insufficent pairs 29692 - Using previous alpha of 0.01736199430775685
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_033628.pvol.h5
# 13.2769153922767
# 0.0005370554829788582 0.006637641358645479 0.020064028433116936 0.05 13.2769153922767
# 33085 pairs found, finding Z-ZDR slope
# slope value 0.050555676353328347
# alpha value 0.020064028433116936
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_034228.pvol.h5
# 13.242310085688436
# 0.000537498430903188 0.006643759576850284 0.020081220349429982 0.05 13.242310085688436
# insufficent pairs 4073 - Using previous alpha of 0.020064028433116936
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_034828.pvol.h5
# 13.372864173475302
# 0.0005358273385795161 0.006620677614129566 0.020016361078617467 0.05 13.372864173475302
# insufficent pairs 8744 - Using previous alpha of 0.020064028433116936
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_035428.pvol.h5
# 13.352908556933011
# 0.0005360827704712574 0.006624205767134243 0.02002627502891568 0.05 13.352908556933011
# insufficent pairs 13736 - Using previous alpha of 0.020064028433116936
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_040028.pvol.h5
# 13.239374427821316
# 0.0005375360073238872 0.00664427860116119 0.02008267878425837 0.05 13.239374427821316
# insufficent pairs 19017 - Using previous alpha of 0.020064028433116936
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_040631.pvol.h5
# 13.354138437342257
# 0.0005360670280020191 0.006623988324277888 0.020025664024328364 0.05 13.354138437342257
# insufficent pairs 24627 - Using previous alpha of 0.020064028433116936
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_041228.pvol.h5
# 13.454114744235538
# 0.0005347873312737851 0.006606312513219156 0.019975995795063782 0.05 13.454114744235538
# 30779 pairs found, finding Z-ZDR slope
# slope value 0.06674035859896853
# alpha value 0.019975995795063782
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_041828.pvol.h5
# 13.437955899913433
# 0.000534994164481108 0.006609169396895305 0.019984023508923004 0.05 13.437955899913433
# insufficent pairs 7039 - Using previous alpha of 0.019975995795063782
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_042431.pvol.h5
# 13.414533568391752
# 0.0005352939703245856 0.006613310465108338 0.019995659723222977 0.05 13.414533568391752
# insufficent pairs 14562 - Using previous alpha of 0.019975995795063782
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_043028.pvol.h5
# 13.483140343372781
# 0.0005344158036048284 0.006601180787291692 0.019961575877412402 0.05 13.483140343372781
# insufficent pairs 22728 - Using previous alpha of 0.019975995795063782
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_043628.pvol.h5
# 13.333867357226614
# 0.0005363264978274993 0.006627572251242334 0.02003573469692982 0.05 13.333867357226614
# 31148 pairs found, finding Z-ZDR slope
# slope value 0.06237416664028866
# alpha value 0.02003573469692982
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_044228.pvol.h5
# 13.228202096932387
# 0.0005376790131592655 0.0066462538692623535 0.02008822919824399 0.05 13.228202096932387
# insufficent pairs 8182 - Using previous alpha of 0.02003573469692982
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_044828.pvol.h5
# 13.028940540622756
# 0.0005402295610800287 0.006681483312417896 0.020187222339418612 0.05 13.028940540622756
# insufficent pairs 16378 - Using previous alpha of 0.02003573469692982
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_045428.pvol.h5
# 13.08354417974688
# 0.0005395306344992399 0.00667182938902075 0.020160095251501746 0.05 13.08354417974688
# insufficent pairs 24600 - Using previous alpha of 0.02003573469692982
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_050031.pvol.h5
# 13.244599295586346
# 0.0005374691290164948 0.006643354844540333 0.020080083069952702 0.05 13.244599295586346
# 33063 pairs found, finding Z-ZDR slope
# slope value 0.06089409315849048
# alpha value 0.020080083069952702
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_050631.pvol.h5
# 13.197142053056954
# 0.000538076581720871 0.006651745285019529 0.020103659828041305 0.05 13.197142053056954
# insufficent pairs 8671 - Using previous alpha of 0.020080083069952702
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_051228.pvol.h5
# 13.159872358924332
# 0.0005385536338057685 0.006658334566942177 0.020122175412086392 0.05 13.159872358924332
# insufficent pairs 17689 - Using previous alpha of 0.020080083069952702
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_051828.pvol.h5
# 13.077425005529136
# 0.000539608959929227 0.006672911259022448 0.020163135257253124 0.05 13.077425005529136
# insufficent pairs 27152 - Using previous alpha of 0.020080083069952702
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_052431.pvol.h5
# 13.443516355770829
# 0.0005349229906461334 0.006608186308299717 0.01998126107445305 0.05 13.443516355770829
# 37456 pairs found, finding Z-ZDR slope
# slope value 0.06058328462874185
# alpha value 0.01998126107445305
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_053028.pvol.h5
# 13.74543165107521
# 0.0005310584748662373 0.006554807684089902 0.019831269555745837 0.05 13.74543165107521
# insufficent pairs 11087 - Using previous alpha of 0.01998126107445305
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_053628.pvol.h5
# 14.050535095957912
# 0.0005271531507717387 0.00650086539503464 0.019679694164328104 0.05 14.050535095957912
# insufficent pairs 23011 - Using previous alpha of 0.01998126107445305
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_054228.pvol.h5
# 14.175975638460727
# 0.0005255475118277027 0.006478687507120143 0.019617375302812712 0.05 14.175975638460727
# 35253 pairs found, finding Z-ZDR slope
# slope value 0.0669342957656173
# alpha value 0.019617375302812712
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_054828.pvol.h5
# 14.204258970201938
# 0.0005251854851814152 0.0064736870140682965 0.019603324143603676 0.05 14.204258970201938
# insufficent pairs 12990 - Using previous alpha of 0.019617375302812712
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_055428.pvol.h5
# 14.220193418190897
# 0.0005249815242471565 0.006470869803663849 0.019595407909842762 0.05 14.220193418190897
# insufficent pairs 26642 - Using previous alpha of 0.019617375302812712
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_060028.pvol.h5
# 14.188967803887516
# 0.0005253812121102399 0.006476390492272686 0.019610920795028682 0.05 14.188967803887516
# 40247 pairs found, finding Z-ZDR slope
# slope value 0.0654017971061608
# alpha value 0.019610920795028682
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_060628.pvol.h5
# 14.011577483659512
# 0.0005276518082091583 0.006507753100888998 0.019699048306117954 0.05 14.011577483659512
# insufficent pairs 13371 - Using previous alpha of 0.019610920795028682
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_061228.pvol.h5
# 13.70759531322082
# 0.0005315427799907735 0.006561497148622558 0.019850066648391895 0.05 13.70759531322082
# insufficent pairs 26455 - Using previous alpha of 0.019610920795028682
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_061828.pvol.h5
# 13.739053689740341
# 0.0005311401127713236 0.006555935307653906 0.019834438126936995 0.05 13.739053689740341
# 39656 pairs found, finding Z-ZDR slope
# slope value 0.0724508659147164
# alpha value 0.019834438126936995
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_062428.pvol.h5
# 13.948865213858372
# 0.0005284545252626128 0.006518840630189839 0.01973020376175516 0.05 13.948865213858372
# insufficent pairs 14209 - Using previous alpha of 0.019834438126936995
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_063028.pvol.h5
# 14.083126696018399
# 0.0005267359782909645 0.006495103200143947 0.019663502657418057 0.05 14.083126696018399
# insufficent pairs 29966 - Using previous alpha of 0.019834438126936995
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_063628.pvol.h5
# 14.2711272385406
# 0.0005243295713466803 0.006461864704226021 0.01957010398789303 0.05 14.2711272385406
# 47264 pairs found, finding Z-ZDR slope
# slope value 0.06710533872246739
# alpha value 0.01957010398789303
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_064228.pvol.h5
# 14.496045662525965
# 0.0005214506155196677 0.0064220991268654085 0.0194583645148571 0.05 14.496045662525965
# insufficent pairs 17598 - Using previous alpha of 0.01957010398789303
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_064828.pvol.h5
# 14.63031141648924
# 0.0005197320138689378 0.006398360941564702 0.019391661288288148 0.05 14.63031141648924
# 35439 pairs found, finding Z-ZDR slope
# slope value 0.0622580282609252
# alpha value 0.019391661288288148
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_065431.pvol.h5
# 14.79368887137537
# 0.0005176407824463953 0.006369475807540834 0.019310495368700716 0.05 14.79368887137537
# insufficent pairs 18226 - Using previous alpha of 0.019391661288288148
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_070028.pvol.h5
# 14.932623008405015
# 0.0005158624254924158 0.006344912252113992 0.019241472889424387 0.05 14.932623008405015
# 36786 pairs found, finding Z-ZDR slope
# slope value 0.05709165836520051
# alpha value 0.019241472889424387
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_070628.pvol.h5
# 15.151327787094141
# 0.000513063004325195 0.006306245247241755 0.01913282035537163 0.05 15.151327787094141
# insufficent pairs 18342 - Using previous alpha of 0.019241472889424387
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_071231.pvol.h5
# 15.278109857553622
# 0.0005114401938233137 0.0062838301771845195 0.01906983502276736 0.05 15.278109857553622
# 36504 pairs found, finding Z-ZDR slope
# slope value 0.055724003713797085
# alpha value 0.01906983502276736
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_071828.pvol.h5
# 15.412247348763962
# 0.0005097232339358214 0.0062601146687385305 0.019003195517134065 0.05 15.412247348763962
# insufficent pairs 18294 - Using previous alpha of 0.01906983502276736
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_072428.pvol.h5
# 15.60759292726172
# 0.0005072228105310499 0.0062255775704601266 0.018906147833736377 0.05 15.60759292726172
# 36070 pairs found, finding Z-ZDR slope
# slope value 0.049056703772614965
# alpha value 0.018906147833736377
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_073028.pvol.h5
# 15.711112702421701
# 0.0005058977574090022 0.006207275274211842 0.018854719209436897 0.05 15.711112702421701
# insufficent pairs 17656 - Using previous alpha of 0.018906147833736377
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_073628.pvol.h5
# 15.856842218959759
# 0.0005040324195973151 0.006181510295687914 0.01878232078562079 0.05 15.856842218959759
# 35549 pairs found, finding Z-ZDR slope
# slope value 0.04683020833660573
# alpha value 0.01878232078562079
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_074228.pvol.h5
# 16.008375988465307
# 0.0005020927873476441 0.006154719125239333 0.018707038808930435 0.05 16.008375988465307
# insufficent pairs 18671 - Using previous alpha of 0.01878232078562079
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_074828.pvol.h5
# 16.178462283175527
# 0.0004999156827753533 0.006124647868334566 0.018622539937718396 0.05 16.178462283175527
# 38099 pairs found, finding Z-ZDR slope
# slope value 0.05189219954259252
# alpha value 0.018622539937718396
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_075428.pvol.h5
# 16.288547599901914
# 0.0004985065907212555 0.006105184784337341 0.018567849552368728 0.05 16.288547599901914
# insufficent pairs 19788 - Using previous alpha of 0.018622539937718396
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_080031.pvol.h5
# 16.922891432972538
# 0.0004903869896579515 0.0059930327946504545 0.01825270753609924 0.05 16.922891432972538
# 41030 pairs found, finding Z-ZDR slope
# slope value 0.05665328921202348
# alpha value 0.01825270753609924
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_080628.pvol.h5
# 17.1788698189366
# 0.0004871104663176115 0.005947775816012009 0.018125537473952298 0.05 17.1788698189366
# insufficent pairs 22950 - Using previous alpha of 0.01825270753609924
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_081231.pvol.h5
# 17.362389522157123
# 0.00048476141411638886 0.005915329532482619 0.01803436488539234 0.05 17.362389522157123
# 48387 pairs found, finding Z-ZDR slope
# slope value 0.05569392543505217
# alpha value 0.01803436488539234
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_081828.pvol.h5
# 17.442340197324217
# 0.00048373804547425007 0.005901194253113078 0.01799464538996933 0.05 17.442340197324217
# insufficent pairs 28088 - Using previous alpha of 0.01803436488539234
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_082428.pvol.h5
# 17.57453450928589
# 0.0004820459582811406 0.005877822298758254 0.01792897125578677 0.05 17.57453450928589
# 57591 pairs found, finding Z-ZDR slope
# slope value 0.03832705137045943
# alpha value 0.018454995366986443
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_083028.pvol.h5
# 17.40510333441552
# 0.0004842146773194813 0.005907777730475335 0.018013144663462367 0.05 17.40510333441552
# insufficent pairs 29113 - Using previous alpha of 0.018454995366986443
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_083630.pvol.h5
# 17.06127458998962
# 0.0004886156852481329 0.0059685666524898345 0.01818395878369316 0.05 17.06127458998962
# 57446 pairs found, finding Z-ZDR slope
# slope value 0.050001584848060304
# alpha value 0.01818395878369316
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_084228.pvol.h5
# 16.561792394981158
# 0.0004950090573442411 0.00605687510456733 0.01843210153817336 0.05 16.561792394981158
# insufficent pairs 25978 - Using previous alpha of 0.01818395878369316
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_084831.pvol.h5
# 15.892712921901397
# 0.0005035732745996621 0.006175168355407832 0.018764500220399383 0.05 15.892712921901397
# 49422 pairs found, finding Z-ZDR slope
# slope value 0.04558211972608283
# alpha value 0.018764500220399383
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_085428.pvol.h5
# 15.45213019794756
# 0.0005092127334662712 0.006253063381002871 0.01898338171765965 0.05 15.45213019794756
# insufficent pairs 22118 - Using previous alpha of 0.018764500220399383
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_090031.pvol.h5
# 14.6469290057056
# 0.0005195193087269683 0.0063954229517912495 0.019383405669965457 0.05 14.6469290057056
# 43814 pairs found, finding Z-ZDR slope
# slope value 0.04963089985882532
# alpha value 0.019383405669965457
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_090631.pvol.h5
# 14.566911497772383
# 0.0005205435328285136 0.0064095700471938424 0.01942315836790668 0.05 14.566911497772383
# insufficent pairs 20819 - Using previous alpha of 0.019383405669965457
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_091231.pvol.h5
# 14.35044265347494
# 0.0005233143340355208 0.006447841738865629 0.019530700089753647 0.05 14.35044265347494
# 40443 pairs found, finding Z-ZDR slope
# slope value 0.04166054026607203
# alpha value 0.019530700089753647
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_091828.pvol.h5
# 14.180767843154547
# 0.0005254861716076218 0.0064778402453302755 0.01961499453552082 0.05 14.180767843154547
# insufficent pairs 17401 - Using previous alpha of 0.019530700089753647
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_092428.pvol.h5
# 14.10234477334516
# 0.000526489986901182 0.006491705444072575 0.019653955116602125 0.05 14.10234477334516
# 32458 pairs found, finding Z-ZDR slope
# slope value 0.03414191264001761
# alpha value 0.021912340850540255
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_093028.pvol.h5
# 13.826118645591556
# 0.0005300256813364281 0.006540542223459412 0.019791184256870112 0.05 13.826118645591556
# insufficent pairs 12715 - Using previous alpha of 0.021912340850540255
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_093631.pvol.h5
# 13.46463639632372
# 0.0005346526541270564 0.006604452285129966 0.019970768638306376 0.05 13.46463639632372
# insufficent pairs 23490 - Using previous alpha of 0.021912340850540255
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_094228.pvol.h5
# 13.015167268212682
# 0.0005404058589668776 0.006683918426979997 0.020194064901151935 0.05 13.015167268212682
# 32864 pairs found, finding Z-ZDR slope
# slope value 0.03418457205681239
# alpha value 0.022492390683668206
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_094828.pvol.h5
# 12.471967237566469
# 0.0005473588193591492 0.006779956192398248 0.020463926676376976 0.05 12.471967237566469
# insufficent pairs 7619 - Using previous alpha of 0.022492390683668206
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_095428.pvol.h5
# 11.847948868605139
# 0.0005553462544818542 0.006890282640030611 0.020773939002076965 0.05 11.847948868605139
# insufficent pairs 13972 - Using previous alpha of 0.022492390683668206
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_100031.pvol.h5
# 11.248568790434835
# 0.0005630183194824341 0.006996253037851121 0.021071711024911975 0.05 11.248568790434835
# insufficent pairs 19404 - Using previous alpha of 0.022492390683668206
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_100628.pvol.h5
# 11.250505645683717
# 0.0005629935277352484 0.006995910601843118 0.021070748795224328 0.05 11.250505645683717
# insufficent pairs 24648 - Using previous alpha of 0.022492390683668206
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_101228.pvol.h5
# 11.457139891093243
# 0.0005603486093940065 0.006959377667254714 0.020968092902104878 0.05 11.457139891093243
# insufficent pairs 29945 - Using previous alpha of 0.022492390683668206
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_101828.pvol.h5
# 11.620339156982608
# 0.0005582596587906226 0.006930524037045475 0.02088701550681104 0.05 11.620339156982608
# 35268 pairs found, finding Z-ZDR slope
# slope value 0.047168294822468454
# alpha value 0.02088701550681104
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_102428.pvol.h5
# 11.882764203274826
# 0.0005549006181980822 0.00688412728886101 0.020756642743813065 0.05 11.882764203274826
# insufficent pairs 5723 - Using previous alpha of 0.02088701550681104
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_103028.pvol.h5
# 11.940512310602909
# 0.0005541614424242828 0.006873917423485405 0.020727953484092475 0.05 11.940512310602909
# insufficent pairs 11413 - Using previous alpha of 0.02088701550681104
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_103631.pvol.h5
# 12.075604114468252
# 0.0005524322673348064 0.0068500331925620125 0.02066083987593217 0.05 12.075604114468252
# insufficent pairs 17238 - Using previous alpha of 0.02088701550681104
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_104228.pvol.h5
# 12.306857682320473
# 0.0005494722216662979 0.00680914756176574 0.020545953103423185 0.05 12.306857682320473
# insufficent pairs 23165 - Using previous alpha of 0.02088701550681104
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_104828.pvol.h5
# 12.5163976309129
# 0.0005467901103243149 0.006772100898854598 0.02044185365696247 0.05 12.5163976309129
# insufficent pairs 28949 - Using previous alpha of 0.02088701550681104
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_105431.pvol.h5
# 12.491726931796945
# 0.0005471058952729991 0.0067764626784582995 0.020454110060283276 0.05 12.491726931796945
# 34631 pairs found, finding Z-ZDR slope
# slope value 0.04715852544588199
# alpha value 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_110028.pvol.h5
# 12.298783429079393
# 0.0005495755721077837 0.0068105750897387626 0.020549964392433354 0.05 12.298783429079393
# insufficent pairs 5634 - Using previous alpha of 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_110628.pvol.h5
# 11.877213984455322
# 0.0005549716609989718 0.006885108567548298 0.020759400092522595 0.05 11.877213984455322
# insufficent pairs 11206 - Using previous alpha of 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_111231.pvol.h5
# 11.7012021742386
# 0.0005572246121697459 0.006916227455594615 0.020846842759838263 0.05 11.7012021742386
# insufficent pairs 16417 - Using previous alpha of 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_111828.pvol.h5
# 11.816999340093838
# 0.0005557424084467989 0.006895754516671409 0.02078931472784138 0.05 11.816999340093838
# insufficent pairs 21335 - Using previous alpha of 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_112431.pvol.h5
# 11.869068865975478
# 0.0005550759185155139 0.006886548624495534 0.020763446587383383 0.05 11.869068865975478
# insufficent pairs 25540 - Using previous alpha of 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_113028.pvol.h5
# 11.826507648368434
# 0.0005556207021008841 0.00689407344776846 0.020784591000290564 0.05 11.826507648368434
# insufficent pairs 28791 - Using previous alpha of 0.020454110060283276
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_113628.pvol.h5
# 12.004388206516806
# 0.0005533438309565849 0.006862624165087828 0.02069621993900245 0.05 12.004388206516806
# 31349 pairs found, finding Z-ZDR slope
# slope value 0.04170238813933201
# alpha value 0.02069621993900245
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_114228.pvol.h5
# 11.99382177802955
# 0.0005534790812412217 0.006864492309644375 0.02070146934067492 0.05 11.99382177802955
# insufficent pairs 2085 - Using previous alpha of 0.02069621993900245
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_114828.pvol.h5
# 11.60238754271419
# 0.0005584894394532584 0.006933697882448131 0.02089593386877959 0.05 11.60238754271419
# insufficent pairs 4010 - Using previous alpha of 0.02069621993900245
# processing /jobfs/7705106.gadi-pbs/tmp39k4snre/02_20200119_115428.pvol.h5
