# %%
import os
from glob import glob
from datetime import datetime

import pyart
from matplotlib import pyplot as plt
import cartopy.crs as ccrs # A toolkit for map projections
import numpy as np
from netCDF4 import Dataset as NetCDFFile 
import matplotlib.dates as mdates

import tqdm
import dask
import dask.bag as db
from dask.diagnostics import ProgressBar

import rainrate

# %%
img_root = '/g/data/kl02/jss548/PST/polarimetric_rain/img'
vol_root = '/g/data/kl02/jss548/PST/polarimetric_rain/cfradial'
grid_root = '/g/data/kl02/jss548/PST/polarimetric_rain/rf3_instant_rainrate'
date_str = '20200119'
radar_name = '02'
plot_range_km = 100
NCPU = 8
band = 'C'
sweep = 2

# %%
def chunks(l, n):
    """
    Yield successive n-sized chunks from l.
    From http://stackoverflow.com/a/312464
    """
    for i in range(0, len(l), n):
        yield l[i:i + n]

def plot_ppi(radar, display, subplot_id, fig, field_name, sweep, vmin, vmax):
    #get lat lon
    lon_range = 1.0
    lat_range = 1.0
    radar_lon = radar.longitude['data']
    radar_lat = radar.latitude['data']
    lon_min = radar_lon-lon_range
    lon_max = radar_lon+lon_range
    lat_min = radar_lat-lat_range
    lat_max = radar_lat+lat_range    
    
    #create subplot
    ax = fig.add_subplot(subplot_id, projection=ccrs.PlateCarree())
    ax.set_extent([lon_min, lon_max, lat_min, lat_max], crs=ccrs.PlateCarree())
    #plot data
    display.plot_ppi_map(field_name, sweep, 
                       colorbar_flag=True,
                       vmin=vmin, vmax=vmax, cmap='pyart_HomeyerRainbow',
                       resolution='10m')
    #add range rings
    display.plot_range_rings(np.linspace(0,150,6, dtype=np.float), ax=ax, col='k', ls='-', lw=0.5)
    
    #Now we add lat lon lines
    gl = display.ax.gridlines(draw_labels=True,
                              linewidth=1, color='gray', alpha=0.5,
                              linestyle='--')
    gl.xlabel_style = {'size': 10}
    gl.ylabel_style = {'size': 10}
    gl.xlabels_top = False
    gl.ylabels_right = False
    
def ppi_manager(vol_ffn):
    #print('processing',vol_ffn)
    
    #read volume
    radar = pyart.io.read_cfradial(vol_ffn)
    display = pyart.graph.RadarMapDisplay(radar)
    
    #create figure
    fig = plt.figure(figsize=[15,15], facecolor='w')
    #plot data
    plot_ppi(radar, display, 221, fig, 'PHIDP_VAL', 0, 0, 90)
    plot_ppi(radar, display, 222, fig, 'corrected_reflectivity', 0, 10, 60)
    plot_ppi(radar, display, 223, fig, 'specific_attenuation', 0, 0, 0.04)
    plot_ppi(radar, display, 224, fig, 'hybrid_rainrate', 0, 0, 70)

    #save image to file
    #create paths
    img_path = f'{img_root}/ppi/{radar_name}/{date_str}'
    if not os.path.exists(img_path):
        try:
            os.makedirs(img_path)
        except:
            pass
    img_fn = f'{os.path.basename(vol_ffn)[:-3]}_{plot_range_km}km.png'  #this filename should match
    img_ffn = f'{img_path}/{img_fn}'
    
    plt.savefig(img_ffn, dpi=100)  # Saving figure. 
    plt.close()  # Release memory 
    fig.clf()  # Clear figure 
    
def plot_grid(grid_ffn):
    #read grid
    nc = NetCDFFile(grid_ffn)
    rainrate = nc.variables['rain_rate'][:] # rainrate
    x = nc.variables['x'][:] # x
    y = nc.variables['y'][:] # y
    x_grid,y_grid=np.meshgrid(x,y)
    #create figure
    fig = plt.figure(figsize=[15,12], facecolor='w')    
    #plot
    im = plt.pcolormesh(x_grid, y_grid, rainrate, cmap='hot_r', vmin=0, vmax=100)
    cbar = fig.colorbar(im)
    cbar.set_label('Rainrate (mm/hr)', rotation=270)
    plt.grid()
    plt.xlabel('Distance E-W (km)')
    plt.ylabel('Distance N-S (km)')
    #close file
    nc.close()
    
    #save grid
    #create paths
    img_path = f'{img_root}/rf3_grid/{radar_name}/{date_str}'
    if not os.path.exists(img_path):
        try:
            os.makedirs(img_path)
        except:
            pass
    img_fn = f'{os.path.basename(grid_ffn)[:-3]}.png'  #this filename should match
    img_ffn = f'{img_path}/{img_fn}'
    
    plt.savefig(img_ffn, dpi=100)  # Saving figure. 
    plt.close()  # Release memory 
    fig.clf()  # Clear figure 
    
def load_alpha(vol_ffn_list):
    
    #load alpha list
    alpha_list = []
    alpha_method_list = []
    dt_list = []
    for vol_ffn in tqdm. tqdm(vol_ffn_list):
        #read data
        nc = NetCDFFile(vol_ffn)
        dt_list.append(datetime.strptime(nc.variables['time'].units[14:], '%Y-%m-%dT%H:%M:%SZ'))
        alpha_list.append(nc.variables['specific_attenuation'].alpha)
        alpha_method_list.append(nc.variables['specific_attenuation'].alpha_method)
        nc.close()
        
    return dt_list, alpha_list, alpha_method_list

def plot_alpha(dt_list, alpha_list, alpha_method_list, date_str):
    
    myFmt = mdates.DateFormatter('%H')
    
    #setup figure
    fig = plt.figure(figsize=[10,5])
    ax1 = plt.subplot(111)
    ax2 = ax1.twinx()
    #plot alpha
    ax1.plot(dt_list, alpha_list, 'b-')
    ax1.set_ylim([0,0.05])
    ax1.set_ylabel(r"$ \alpha (dB deg^{-1})$", color='b')
    #plot method on secondary axis
    ax2.plot(dt_list, alpha_method_list, 'r-')
    ax2.set_ylim([0,5.1])
    ax2.set_ylabel('alpha technique', color='r')
    #annotations
    ax1.set_xlabel('Hour (UTC)')
    plt.title('Alpha timeseries for ' + dt_list[0].strftime('%Y-%m-%d'))
    ax1.grid()
    ax1.xaxis.set_major_formatter(myFmt)
    
    #save plot
    #create paths
    img_path = f'{img_root}/alpha_ts/{radar_name}/'
    if not os.path.exists(img_path):
        try:
            os.makedirs(img_path)
        except:
            pass
    img_fn = f'{radar_name}_{date_str}_alpha_ts.png'  #this filename should match
    img_ffn = f'{img_path}/{img_fn}'
    
#     plt.savefig(img_ffn, dpi=100)  # Saving figure. 
#     plt.close()  # Release memory 
#     fig.clf()  # Clear figure

# %%
#plot volumes
vol_ffn_list = sorted(glob(f'{vol_root}/{radar_name}/{date_str}/*.nc'))

# for vol_ffn in vol_ffn_list[60:]:
#     ppi_manager(vol_ffn)
#     break

#run matching
i            = 0
n_files      = len(vol_ffn_list)   
for flist_chunk in chunks(vol_ffn_list, NCPU):
    bag = db.from_sequence(flist_chunk).map(ppi_manager)
    _ = bag.compute()
    i += NCPU
    del bag
    print('processed: ' + str(round(i/n_files*100,2)))
# Out:
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_000028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_004231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_000628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_003031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_001228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_001828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_002428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_003628.vol.nc
# processed: 3.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_004828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_010630.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_005428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_011828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_011228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_012428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_013028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_010031.vol.nc
# processed: 6.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_013628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_014228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_014828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_021828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_015428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_021231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_020628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_020028.vol.nc
# processed: 10.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_022428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_023031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_023628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_024828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_030630.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_024228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_025428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_030028.vol.nc
# processed: 13.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_031228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_032431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_031828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_033028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_034228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_034828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_033628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_035428.vol.nc
# processed: 16.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_040028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_040631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_041228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_041828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_043628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_043028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_044228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_042431.vol.nc
# processed: 20.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_044828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_050031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_045428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_050631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_051828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_051228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_053028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_052431.vol.nc
# processed: 23.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_053628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_054228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_054828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_055428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_060028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_061228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_060628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_061828.vol.nc
# processed: 26.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_062428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_063028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_063628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_064228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_065431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_070028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_070628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_064828.vol.nc
# processed: 30.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_071231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_071828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_073028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_073628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_074828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_074228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_072428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_075428.vol.nc
# processed: 33.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_080031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_082428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_080628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_081231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_081828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_083630.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_083028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_084228.vol.nc
# processed: 36.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_084831.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_085428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_090031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_090631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_091231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_091828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_092428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_093028.vol.nc
# processed: 40.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_093631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_101828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_095428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_094228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_094828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_100031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_100628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_101228.vol.nc
# processed: 43.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_102428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_103028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_103631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_104228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_105431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_110028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_104828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_110628.vol.nc
# processed: 46.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_111231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_111828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_113028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_112431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_115428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_113628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_114228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_114828.vol.nc
# processed: 50.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_120028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_120628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_121228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_121828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_122428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_123631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_123028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_124231.vol.nc
# processed: 53.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_124828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_130628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_125428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_130028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_131828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_131228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_132428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_133028.vol.nc
# processed: 56.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_133631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_134228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_134828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_135431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_140628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_140028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_141228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_141831.vol.nc
# processed: 60.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_144231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_143028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_145428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_150630.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_144831.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_142428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_143628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_150028.vol.nc
# processed: 63.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_151228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_151828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_152428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_153028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_154828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_155428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_153628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_154231.vol.nc
# processed: 66.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_160028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_160628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_161228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_161828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_163028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_162428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_163628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_164228.vol.nc
# processed: 70.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_164828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_165431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_171228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_170628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_173028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_171828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_170028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_172431.vol.nc
# processed: 73.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_174228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_175431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_174831.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_181228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_173628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_181828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_180628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_180028.vol.nc
# processed: 76.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_182428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_183031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_183628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_184228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_184828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_185428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_190628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_190031.vol.nc
# processed: 80.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_191231.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_192428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_194828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_191828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_194228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_193628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_193028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_195428.vol.nc
# processed: 83.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_200031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_200631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_201228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_203628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_203028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_202428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_201828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_204231.vol.nc
# processed: 86.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_204828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_210628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_205428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_210028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_211228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_213028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_212431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_211828.vol.nc
# processed: 90.0
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_213628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_214828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_214228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_215428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_220628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_220028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_221228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_221831.vol.nc
# processed: 93.33
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_222428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_223028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_223628.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_224228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_224828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_225428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_230028.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_230628.vol.nc
# processed: 96.67
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_231228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_232428.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_231828.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_233631.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_235431.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_234228.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_233031.vol.nc
# processing /g/data/kl02/jss548/PST/polarimetric_rain/cfradial/02/20200119/02_20200119_234828.vol.nc
# processed: 100.0

# %%
#plot grid
grid_ffn_list = sorted(glob(f'{grid_root}/{radar_name}/{date_str}/*.nc'))

# for grid_ffn in grid_ffn_list[60:]:
#     plot_grid(grid_ffn)
#     break
    
#run matching
i            = 0
n_files      = len(grid_ffn_list)   
for flist_chunk in chunks(grid_ffn_list, NCPU):
    bag = db.from_sequence(flist_chunk).map(plot_grid)
    _ = bag.compute()
    i += NCPU
    del bag
    print('processed: ' + str(round(i/n_files*100,2)))
# Out:
# processed: 3.33
# processed: 6.67
# processed: 10.0
# processed: 13.33
# processed: 16.67
# processed: 20.0
# processed: 23.33
# processed: 26.67
# processed: 30.0
# processed: 33.33
# processed: 36.67
# processed: 40.0
# processed: 43.33
# processed: 46.67
# processed: 50.0
# processed: 53.33
# processed: 56.67
# processed: 60.0
# processed: 63.33
# processed: 66.67
# processed: 70.0
# processed: 73.33
# processed: 76.67
# processed: 80.0
# processed: 83.33
# processed: 86.67
# processed: 90.0
# processed: 93.33
# processed: 96.67
# processed: 100.0

# %%
#plot alpha timeseries
vol_ffn_list = sorted(glob(f'{vol_root}/{radar_name}/{date_str}/*.nc'))
dt_list, alpha_list, alpha_method_list = load_alpha(vol_ffn_list)
plot_alpha(dt_list, alpha_list, alpha_method_list, date_str)
# Out:
# 100%|██████████| 240/240 [01:30<00:00,  2.66it/s]
